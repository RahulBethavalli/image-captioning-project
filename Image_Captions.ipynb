# %%
import os
import numpy as np
import torch
import cv2
import re
from tqdm import tqdm
from collections import Counter

# %%
vocab_freq = Counter()
img_captions_dict = {}
with open('Flickr8k_text/Flickr8k.token.txt', 'r') as f:
    lines = f.readlines()
    for line in lines:
        img_id = line.split('\t')[0].split('#')[0]
        caption = line.split('\t')[1].strip().strip('.').strip()
        clean_caption = re.sub("[^A-Za-z']+", ' ', caption.replace('<br />', ' ')).lower()
        vocab_freq.update(clean_caption.split())
        if img_id not in img_captions_dict:
            img_captions_dict[img_id] = []
        img_captions_dict[img_id].append(clean_caption)

# %%
words = [w for w in vocab_freq.keys() if vocab_freq[w] > 5]

# %%
word_map = {word:i+3 for i, word in enumerate(words)}

# %%
word_map['<start>'] = 0
word_map['<end>'] = 1
word_map['<unk>'] = 2

# %%
def fetch_encoded_img_captions(file, img_captions_dict, word_map, max_len = 50):
    img_arrays = []
    encoded_captions = []
    with open(file, 'r') as f:
        img_ids = f.readlines()
        for img_id in img_ids:
            img_id = img_id.strip()
            if img_id not in img_captions_dict:
                continue
            img = cv2.imread('Flicker8k_Dataset/' + img_id)
            img = cv2.resize(img, (256, 256))
            img_arrays.append(img)
            caption_list = img_captions_dict[img_id]
            for caption in caption_list:
                caption = caption.split()
                if len(caption) > max_len:
                    caption = caption[:max_len]
                enc_caption = [word_map['<start>']] + [word_map.get(word, word_map['<unk>']) for word in caption] \
                              + [word_map['<end>']]
                encoded_captions.append(enc_caption)
    return img_arrays, encoded_captions

# %%
train_imgs, train_captions = fetch_encoded_img_captions('Flickr8k_text/Flickr_8k.trainImages.txt', 
                                                                              img_captions_dict, word_map)

# %%
assert len(train_imgs)*5 == len(train_captions)

# %%
train_imgs[0].shape
# Out:
# (256, 256, 3)

# %%
valid_imgs, valid_captions = fetch_encoded_img_captions('Flickr8k_text/Flickr_8k.devImages.txt', 
                                                                              img_captions_dict, word_map)
test_imgs, test_captions = fetch_encoded_img_captions('Flickr8k_text/Flickr_8k.testImages.txt', 
                                                                              img_captions_dict, word_map)

# %%
train_imgs = train_imgs[:500]
train_captions = train_captions[:2500]

valid_imgs = valid_imgs[:100]
valid_captions = valid_captions[:500]

# %%
valid_captions[0]
# Out:
# [0,
#  23,
#  139,
#  88,
#  187,
#  356,
#  38,
#  3,
#  386,
#  8,
#  234,
#  925,
#  244,
#  23,
#  91,
#  78,
#  174,
#  139,
#  1]

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torchvision
from torchvision import models, transforms
import albumentations as A
from albumentations.pytorch import ToTensorV2

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class Encoder(nn.Module):
    
    def __init__(self):
        super(Encoder, self).__init__()
        
        resnet = torchvision.models.resnet101(pretrained=True)
        for param in resnet.parameters():
            param.requires_grad_(False)
            
        layers = list(resnet.children())[:-2]
        self.resnet = nn.Sequential(*layers)
        
    def forward(self, x):
        
        x = self.resnet(x)
        
        batch_size, feature_length, size_1,  size_2 = x.size()
        x = x.permute(0, 2, 3, 1)
        x = x.view(batch_size, size_1*size_2, feature_length)
        return x
    
class Attention(nn.Module):
    
    def __init__(self, feature_size, hidden_size, output_size = 1):
        super(Attention, self).__init__()
        
        self.feature_size = feature_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        
        self.Wa = nn.Linear(self.feature_size, self.hidden_size)
        self.Ua = nn.Linear(self.hidden_size, self.hidden_size)
        self.Va = nn.Linear(self.hidden_size, self.output_size)
        
    
    def forward(self, features, decoder_hidden_state):
        
        decoder_hidden_state = decoder_hidden_state.unsqueeze(1)
        att1 = self.Wa(features)
        att2 = self.Ua(decoder_hidden_state)
        
        atten = torch.tanh(att1 + att2)
        att_score = self.Va(atten)
        att_weight = nn.functional.softmax(att_score)
        
        att_sum = torch.sum(att_weight*features, dim=1)
        att_weight = att_weight.squeeze(dim=2)
        
        return att_sum, att_weight
        
        
    
class DecoderAttention(nn.Module):
    
    def __init__(self, feature_size, emb_size, hidden_size, vocab_size, p = 0.5):
        
        super(DecoderAttention, self).__init__()
        
        self.feature_size = feature_size
        self.vocab_size = vocab_size
        self.embed_size = emb_size
        self.hidden_size = hidden_size
        self.p = p
        
        self.embeddings = nn.Embedding(vocab_size, emb_size)
        
        self.lstm = nn.LSTMCell(emb_size + feature_size, hidden_size)
        self.hidden = nn.Linear(feature_size, hidden_size)
        self.cell = nn.Linear(feature_size, hidden_size)
        
        self.fc = nn.Linear(hidden_size, vocab_size)
        
        self.dropout = nn.Dropout(p=p)
        
        self.attention = Attention(feature_size, hidden_size)
        
    
    def forward(self, features, captions):
        
        emb_captions = self.embeddings(captions)
        
        feature_size = features.size(1)
        batch_size = features.size(0)
        cap_len = captions.size(1)
        
        h, c = self.init_hidden(features)
        
        outputs = torch.zeros(batch_size, cap_len, self.vocab_size)
        att_weights = torch.zeros(batch_size, cap_len, feature_size)
        
        for i in range(cap_len):
            sample_prob = 0.0 if i == 0 else 0.5
            use_sampling = np.random.random() < sample_prob
            if use_sampling == False:
                word_embed = emb_captions[:,i,:]
            
            att_sum, att_weight = self.attention(features, h)
            
            lstm_input = torch.cat([word_embed, att_sum], 1)
            h, c = self.lstm(lstm_input, (h,c))
            h = self.dropout(h)
            output = self.fc(h)
            if use_sampling == True:
                
                scaled_output = output / 0.5
                scoring = nn.functional.log_softmax(scaled_output, dim=1)
                top_idx = scoring.topk(1)[1]
                word_embed = self.embeddings(top_idx).squeeze(1) 
            outputs[:, i, :] = output
            att_weights[:, i, :] = att_weight
        return outputs, att_weights
    
    
    def init_hidden(self, features):
        
        mean_features = torch.mean(features, dim=1)
        h0 = self.hidden(mean_features)
        c0 = self.cell(mean_features)
        return h0, c0
    
    def greedy_search(self, feature, max_cap_len = 50):
        
        weights = []
        sentence = []
        
        input_word = torch.tensor(0).unsqueeze(0)
        
        h, c = self.init_hidden(features)
        
        while True:
            emb_word = self.embeddings(input_word)
            att_sum, att_weight = self.attention(features, h)
            
            input_lstm = torch.cat([emb_word, att_sum], dim=1)
            h, c = self.lstm(input_lstm, (h, c))
            
            h = self.dropout(h)
            
            output = self.fc(h)
            
            weights.append(att_weight)
            scores = nn.functional.softmax(output, dim=1)
            idx = scoring[0].topk(1)[1]
            sentence.append(idx.item())
            
            input_word = idx
            if (len(sentence) >= max_sentence or idx == 1):
                break

        return sentence, weights

# %%
class CaptionDataset(Dataset):
    
    def __init__(self, imgs, captions, batch_size, train = True):
        self.imgs = imgs
        self.captions = captions
        self.size = len(self.captions)
        self.is_train = train
        self.batch_size = batch_size
        self.caption_lengths = [len(token) for token in self.captions]
        
        if train:
            self.transforms = A.Compose([ 
                A.RandomCrop(224, 224),                      # get 224x224 crop from random location
                A.HorizontalFlip(p=0.5),               # horizontally flip image with probability=0.5
                A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
                ToTensorV2()
                
            ])
        else:
            self.transforms = A.Compose([ 
                A.CenterCrop(224, 224),                   # smaller edge of image resized to 256
                A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
                ToTensorV2()
            ])
        
    def __len__(self):
        return self.size
    
    def __getitem__(self, idx):
        
        img = self.imgs[idx // 5]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        transformed = self.transforms(image=img.astype(np.uint8))
        img = transformed['image']

        caption = torch.LongTensor(self.captions[idx])
        all_caption_per_image = []
        if self.is_train:
            return img, caption
        for k in range(idx - (idx % 5) , idx - (idx % 5) + 5):
            all_caption_per_image.append(self.captions[k])
        #print(all_caption_per_image)
        caps = get_references(all_caption_per_image)
        caps = [' '.join(cap) for cap in caps]
        return img, caption, caps
    
    def get_indices(self):
        # randomly select the caption length from the list of lengths
        sel_length = np.random.choice(self.caption_lengths)
        all_indices = np.where([self.caption_lengths[i] == sel_length for i in np.arange(len(self.caption_lengths))])[0]
        # select m = batch_size captions from list above
        indices = list(np.random.choice(all_indices, size=self.batch_size))
        # return the caption indices of specified batch
        return indices
    

def get_loader(batch_size=1, train = True):
    
    if train:
        # Randomly sample a caption length and indices of that length
        dataset = CaptionDataset(train_imgs, train_captions,batch_size=batch_size, train = True)
        indices = dataset.get_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices
        # functionality from torch.utils
        initial_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader = data.DataLoader(dataset=dataset,
                                      batch_sampler=data.sampler.BatchSampler(sampler=initial_sampler,
                                                                              batch_size=dataset.batch_size,
                                                                              drop_last=False))
    else:
        dataset = CaptionDataset(valid_imgs, valid_captions, batch_size=batch_size, train = False)
        indices = dataset.get_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices
        # functionality from torch.utils
        initial_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader = data.DataLoader(dataset=dataset,
                                      batch_sampler=data.sampler.BatchSampler(sampler=initial_sampler,
                                                                              batch_size=dataset.batch_size,
                                                                              drop_last=False))
        


    return data_loader

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import numpy as np
import sys
import os
import math

import torch.utils.data as data

import nltk
from nltk.translate.bleu_score import corpus_bleu
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/rahulbethavalli/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#batch_size = 64          # batch size, change to 64
batch_size = 10
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
feature_size = 2048        # number of feature maps, produced by Encoder
num_epochs = 3             # number of training epochs
print_every = 100          # determines window for printing average loss

# %%
def train(encoder, decoder, optimizer, lossFn, data_loader, total_step):
    
    total_loss = 0.0
    
    for i in tqdm(range(1, total_step+1)):
        encoder.eval()
        decoder.train()
        
        indices = data_loader.dataset.get_indices()
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        img, cap = next(iter(data_loader))
        cap_target = cap[:, 1:]
        cap_train = cap[:, :-1]
        
        encoder.zero_grad()
        decoder.zero_grad()
        
        img_features = encoder(img)
        out, att_weights = decoder(img_features, cap_train)
        
        loss = lossFn(out.view(-1, vocab_size), cap_target.reshape(-1))
        
        loss.backward()
        
        optimizer.step()
        
        total_loss += loss.item()
        
    avg_loss = total_loss / total_step
    print('Avg. Loss train: ', avg_loss)
    return


def validate(encoder, decoder, optimizer, lossFn, data_loader, total_step):
    
        epoch_loss = 0.0
        references = []
        hypothesis = []
        
        for i in range(1, total_step+1):
            # evaluation of encoder and decoder
            encoder.eval()
            decoder.eval()
            
            img, cap, caps_all = next(iter(data_loader))
            
            captions_target = cap[:, 1:]
            val_captions = cap[:, :-1]
            
            features_val = encoder(img)
            outputs_val, atten_weights_val = decoder(captions= val_captions,
                                             features = features_val)
            loss_val = lossFn(outputs_val.view(-1, vocab_size), 
                                 captions_target.reshape(-1))

            # preprocess captions and add them to the list
            
            #print(caps_all)
            #print(len(caps_all))
            #print(caps_all[0].size())
            references.append(caps_all)
            # get corresponding indicies from predictions
            # and form hypothesis from output
            terms_idx = torch.max(outputs_val, dim=2)[1]
            hyp_list = get_hypothesis(terms_idx, data_loader=data_loader)
            hypothesis.append(hyp_list)

            epoch_loss += loss_val.item()

            
        epoch_loss_avg = epoch_loss / total_step

        # prepare the proper shape for computing BLEU scores
        references = np.array(references).reshape(total_step*batch_size, -1)
        #hyps = np.array(hypothesis).reshape(total_step*batch_size, -1)
        hyps = np.concatenate(np.array(hypothesis))
        
        print(hyps)
        bleu_1 = corpus_bleu(references, hyps, weights = (1.0, 0, 0, 0))
        bleu_2 = corpus_bleu(references, hyps, weights = (0.5, 0.5, 0, 0))
        bleu_3 = corpus_bleu(references, hyps, weights = (1.0/3.0, 1.0/3.0, 1.0/3.0, 0))
        bleu_4 = corpus_bleu(references, hyps, weights = (0.25, 0.25, 0.25, 0.25))
        # append individual n_gram scores
        #bleu_score_list.append((bleu_1, bleu_2, bleu_3, bleu_4))

        epoch_stat = 'Avg. Loss valid: %.4f, \
        BLEU-1: %.2f, BLEU-2: %.2f, BLEU-3: %.2f, BLEU-4: %.2f' % (epoch_loss_avg, bleu_1, bleu_2, bleu_3, bleu_4)

        print('\r' + epoch_stat, end="")
        print('\r')
        
        return

# %%
def get_references(caps):
    
    ref_list = []
    
    for cap in caps:
        words = [index2vocab.get(idx) for idx in cap]
        ref_list.append(words)
    return ref_list

# %%
index2vocab = {}

for key, value in word_map.items():
    index2vocab[value] = key

# %%
def get_hypothesis(terms_idx, data_loader):
    
    hypothesis_list = []
    #print(terms_idx)
    #print('--------------------------------')
    for i in range(terms_idx.size(0)):
        words = [index2vocab.get(idx.item()) for idx in terms_idx[i]]
        words = [word for word in words if word not in (',', '.', '<end>')]
        hypothesis_list.append(words)
    return hypothesis_list

# %%
vocab_size = len(vocab_freq) + 2

encoder = Encoder()
decoder = DecoderAttention(feature_size = feature_size, 
                     emb_size = embed_size, 
                     hidden_size = hidden_size, 
                     vocab_size = vocab_size)

lossFn = nn.CrossEntropyLoss()

params = list(decoder.parameters())

optimizer = torch.optim.Adam(params, lr = 1e-4)

data_loader = get_loader(
                         batch_size=batch_size,
                         train = True)

total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)

valid_data_loader = get_loader(batch_size=batch_size, train = False)

total_step_valid = math.ceil(len(valid_data_loader.dataset.caption_lengths) / valid_data_loader.batch_sampler.batch_size)

# %%
for epoch in tqdm(range(num_epochs)):  
    print('Epoch: ', epoch)
    
    train(encoder, decoder, optimizer, lossFn,
          data_loader=data_loader, total_step=total_step)
    
    validate(encoder, decoder, optimizer, lossFn, 
             data_loader= valid_data_loader, total_step= total_step_valid)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch:  0
#   0%|          | 0/250 [00:00<?, ?it/s]<ipython-input-48-144ec9b136c9>:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   att_weight = nn.functional.softmax(att_score)
#
#   0%|          | 1/250 [00:04<16:41,  4.02s/it]
#   1%|          | 2/250 [00:07<15:44,  3.81s/it]
#   1%|          | 3/250 [00:12<18:30,  4.49s/it]
#   2%|▏         | 4/250 [00:16<16:54,  4.12s/it]
#   2%|▏         | 5/250 [00:20<16:27,  4.03s/it]
#   2%|▏         | 6/250 [00:24<16:27,  4.05s/it]
#   3%|▎         | 7/250 [00:28<16:12,  4.00s/it]
#   3%|▎         | 8/250 [00:32<16:24,  4.07s/it]
#   4%|▎         | 9/250 [00:36<16:40,  4.15s/it]
#   4%|▍         | 10/250 [00:42<17:48,  4.45s/it]
#   4%|▍         | 11/250 [00:46<17:12,  4.32s/it]
#   5%|▍         | 12/250 [00:50<17:48,  4.49s/it]
#   5%|▌         | 13/250 [00:55<17:17,  4.38s/it]
#   6%|▌         | 14/250 [00:59<16:53,  4.29s/it]
#   6%|▌         | 15/250 [01:03<16:30,  4.22s/it]
#   6%|▋         | 16/250 [01:07<16:04,  4.12s/it]
#   7%|▋         | 17/250 [01:10<15:26,  3.98s/it]
#   7%|▋         | 18/250 [01:15<16:05,  4.16s/it]
#   8%|▊         | 19/250 [01:19<15:35,  4.05s/it]
#   8%|▊         | 20/250 [01:23<15:55,  4.16s/it]
#   8%|▊         | 21/250 [01:27<15:33,  4.08s/it]
#   9%|▉         | 22/250 [01:32<16:24,  4.32s/it]
#   9%|▉         | 23/250 [01:36<16:24,  4.34s/it]
#  10%|▉         | 24/250 [01:40<15:47,  4.19s/it]
#  10%|█         | 25/250 [01:44<15:09,  4.04s/it]
#  10%|█         | 26/250 [01:48<15:12,  4.07s/it]
#  11%|█         | 27/250 [01:52<14:50,  3.99s/it]
#  11%|█         | 28/250 [01:56<15:00,  4.06s/it]
#  12%|█▏        | 29/250 [02:00<15:08,  4.11s/it]
#  12%|█▏        | 30/250 [02:04<14:54,  4.07s/it]
#  12%|█▏        | 31/250 [02:08<14:58,  4.10s/it]
#  13%|█▎        | 32/250 [02:12<14:52,  4.10s/it]
#  13%|█▎        | 33/250 [02:16<14:28,  4.00s/it]
#  14%|█▎        | 34/250 [02:20<14:02,  3.90s/it]
#  14%|█▍        | 35/250 [02:24<14:05,  3.93s/it]
#  14%|█▍        | 36/250 [02:28<13:51,  3.89s/it]
#  15%|█▍        | 37/250 [02:32<14:07,  3.98s/it]
#  15%|█▌        | 38/250 [02:38<15:56,  4.51s/it]
#  16%|█▌        | 39/250 [02:42<15:33,  4.42s/it]
#  16%|█▌        | 40/250 [02:46<14:57,  4.28s/it]
#  16%|█▋        | 41/250 [02:49<14:16,  4.10s/it]
#  17%|█▋        | 42/250 [02:54<14:29,  4.18s/it]
#  17%|█▋        | 43/250 [02:58<14:09,  4.10s/it]
#  18%|█▊        | 44/250 [03:02<14:36,  4.25s/it]
#  18%|█▊        | 45/250 [03:07<14:37,  4.28s/it]
#  18%|█▊        | 46/250 [03:11<14:25,  4.24s/it]
#  19%|█▉        | 47/250 [03:14<13:37,  4.03s/it]
#  19%|█▉        | 48/250 [03:18<13:32,  4.02s/it]
#  20%|█▉        | 49/250 [03:22<13:12,  3.94s/it]
#  20%|██        | 50/250 [03:26<12:48,  3.84s/it]
#  20%|██        | 51/250 [03:29<12:31,  3.77s/it]
#  21%|██        | 52/250 [03:34<13:17,  4.03s/it]
#  21%|██        | 53/250 [03:38<13:09,  4.01s/it]
#  22%|██▏       | 54/250 [03:42<13:19,  4.08s/it]
#  22%|██▏       | 55/250 [03:46<12:56,  3.98s/it]
#  22%|██▏       | 56/250 [03:50<12:32,  3.88s/it]
#  23%|██▎       | 57/250 [03:53<12:15,  3.81s/it]
#  23%|██▎       | 58/250 [03:58<12:43,  3.98s/it]
#  24%|██▎       | 59/250 [04:01<12:24,  3.90s/it]
#  24%|██▍       | 60/250 [04:06<12:42,  4.01s/it]
#  24%|██▍       | 61/250 [04:09<12:28,  3.96s/it]
#  25%|██▍       | 62/250 [04:14<13:11,  4.21s/it]
#  25%|██▌       | 63/250 [04:18<12:48,  4.11s/it]
#  26%|██▌       | 64/250 [04:22<12:29,  4.03s/it]
#  26%|██▌       | 65/250 [04:26<12:10,  3.95s/it]
#  26%|██▋       | 66/250 [04:30<12:07,  3.95s/it]
#  27%|██▋       | 67/250 [04:34<12:08,  3.98s/it]
#  27%|██▋       | 68/250 [04:38<12:10,  4.02s/it]
#  28%|██▊       | 69/250 [04:42<12:08,  4.03s/it]
#  28%|██▊       | 70/250 [04:46<11:49,  3.94s/it]
#  28%|██▊       | 71/250 [04:50<12:01,  4.03s/it]
#  29%|██▉       | 72/250 [04:54<11:56,  4.02s/it]
#  29%|██▉       | 73/250 [04:57<11:33,  3.92s/it]
#  30%|██▉       | 74/250 [05:02<11:53,  4.06s/it]
#  30%|███       | 75/250 [05:06<11:55,  4.09s/it]
#  30%|███       | 76/250 [05:10<12:11,  4.21s/it]
#  31%|███       | 77/250 [05:15<12:02,  4.18s/it]
#  31%|███       | 78/250 [05:18<11:42,  4.08s/it]
#  32%|███▏      | 79/250 [05:23<11:40,  4.10s/it]
#  32%|███▏      | 80/250 [05:26<11:21,  4.01s/it]
#  32%|███▏      | 81/250 [05:30<11:03,  3.92s/it]
#  33%|███▎      | 82/250 [05:34<11:04,  3.96s/it]
#  33%|███▎      | 83/250 [05:38<11:00,  3.95s/it]
#  34%|███▎      | 84/250 [05:42<10:52,  3.93s/it]
#  34%|███▍      | 85/250 [05:46<11:10,  4.07s/it]
#  34%|███▍      | 86/250 [05:50<10:53,  3.98s/it]
#  35%|███▍      | 87/250 [05:54<10:54,  4.02s/it]
#  35%|███▌      | 88/250 [05:58<10:36,  3.93s/it]
#  36%|███▌      | 89/250 [06:02<10:20,  3.85s/it]
#  36%|███▌      | 90/250 [06:05<10:08,  3.80s/it]
#  36%|███▋      | 91/250 [06:09<10:08,  3.83s/it]
#  37%|███▋      | 92/250 [06:13<10:04,  3.83s/it]
#  37%|███▋      | 93/250 [06:18<10:39,  4.07s/it]
#  38%|███▊      | 94/250 [06:22<10:47,  4.15s/it]
#  38%|███▊      | 95/250 [06:26<10:34,  4.10s/it]
#  38%|███▊      | 96/250 [06:30<10:27,  4.08s/it]
#  39%|███▉      | 97/250 [06:34<09:57,  3.90s/it]
#  39%|███▉      | 98/250 [06:37<09:37,  3.80s/it]
#  40%|███▉      | 99/250 [06:41<09:27,  3.76s/it]
#  40%|████      | 100/250 [06:44<09:24,  3.76s/it]
#  40%|████      | 101/250 [06:49<09:43,  3.92s/it]
#  41%|████      | 102/250 [06:53<09:43,  3.94s/it]
#  41%|████      | 103/250 [06:56<09:20,  3.81s/it]
#  42%|████▏     | 104/250 [07:01<09:36,  3.95s/it]
#  42%|████▏     | 105/250 [07:04<09:20,  3.86s/it]
#  42%|████▏     | 106/250 [07:08<09:21,  3.90s/it]
#  43%|████▎     | 107/250 [07:12<09:01,  3.79s/it]
#  43%|████▎     | 108/250 [07:15<08:36,  3.63s/it]
#  44%|████▎     | 109/250 [07:18<08:22,  3.56s/it]
#  44%|████▍     | 110/250 [07:22<08:10,  3.50s/it]
#  44%|████▍     | 111/250 [07:26<08:47,  3.79s/it]
#  45%|████▍     | 112/250 [07:30<08:40,  3.77s/it]
#  45%|████▌     | 113/250 [07:34<08:44,  3.83s/it]
#  46%|████▌     | 114/250 [07:38<08:38,  3.81s/it]
#  46%|████▌     | 115/250 [07:41<08:24,  3.73s/it]
#  46%|████▋     | 116/250 [07:45<08:06,  3.63s/it]
#  47%|████▋     | 117/250 [07:48<08:00,  3.61s/it]
#  47%|████▋     | 118/250 [07:52<08:00,  3.64s/it]
#  48%|████▊     | 119/250 [07:56<08:10,  3.74s/it]
#  48%|████▊     | 120/250 [08:00<08:03,  3.72s/it]
#  48%|████▊     | 121/250 [08:04<08:19,  3.87s/it]
#  49%|████▉     | 122/250 [08:08<08:10,  3.83s/it]
#  49%|████▉     | 123/250 [08:11<08:09,  3.85s/it]
#  50%|████▉     | 124/250 [08:15<07:52,  3.75s/it]
#  50%|█████     | 125/250 [08:20<08:41,  4.17s/it]
#  50%|█████     | 126/250 [08:24<08:16,  4.01s/it]
#  51%|█████     | 127/250 [08:28<08:10,  3.99s/it]
#  51%|█████     | 128/250 [08:31<07:50,  3.85s/it]
#  52%|█████▏    | 129/250 [08:36<08:04,  4.00s/it]
#  52%|█████▏    | 130/250 [08:39<07:49,  3.91s/it]
#  52%|█████▏    | 131/250 [08:43<07:52,  3.97s/it]
#  53%|█████▎    | 132/250 [08:48<07:57,  4.05s/it]
#  53%|█████▎    | 133/250 [08:52<07:57,  4.08s/it]
#  54%|█████▎    | 134/250 [08:56<07:49,  4.05s/it]
#  54%|█████▍    | 135/250 [08:59<07:30,  3.92s/it]
#  54%|█████▍    | 136/250 [09:03<07:28,  3.93s/it]
#  55%|█████▍    | 137/250 [09:07<07:13,  3.84s/it]
#  55%|█████▌    | 138/250 [09:11<07:04,  3.79s/it]
#  56%|█████▌    | 139/250 [09:15<07:29,  4.05s/it]
#  56%|█████▌    | 140/250 [09:19<07:20,  4.00s/it]
#  56%|█████▋    | 141/250 [09:23<07:10,  3.95s/it]
#  57%|█████▋    | 142/250 [09:27<06:56,  3.85s/it]
#  57%|█████▋    | 143/250 [09:30<06:45,  3.79s/it]
#  58%|█████▊    | 144/250 [09:34<06:29,  3.68s/it]
#  58%|█████▊    | 145/250 [09:37<06:21,  3.63s/it]
#  58%|█████▊    | 146/250 [09:41<06:35,  3.80s/it]
#  59%|█████▉    | 147/250 [09:45<06:27,  3.77s/it]
#  59%|█████▉    | 148/250 [09:49<06:21,  3.74s/it]
#  60%|█████▉    | 149/250 [09:52<06:12,  3.68s/it]
#  60%|██████    | 150/250 [09:56<06:07,  3.68s/it]
#  60%|██████    | 151/250 [10:00<06:01,  3.65s/it]
#  61%|██████    | 152/250 [10:03<05:53,  3.61s/it]
#  61%|██████    | 153/250 [10:07<05:56,  3.67s/it]
#  62%|██████▏   | 154/250 [10:11<06:02,  3.77s/it]
#  62%|██████▏   | 155/250 [10:15<06:00,  3.80s/it]
#  62%|██████▏   | 156/250 [10:19<05:59,  3.83s/it]
#  63%|██████▎   | 157/250 [10:23<06:01,  3.89s/it]
#  63%|██████▎   | 158/250 [10:26<05:47,  3.78s/it]
#  64%|██████▎   | 159/250 [10:29<05:31,  3.64s/it]
#  64%|██████▍   | 160/250 [10:33<05:35,  3.73s/it]
#  64%|██████▍   | 161/250 [10:38<05:44,  3.88s/it]
#  65%|██████▍   | 162/250 [10:41<05:36,  3.83s/it]
#  65%|██████▌   | 163/250 [10:45<05:20,  3.68s/it]
#  66%|██████▌   | 164/250 [10:48<05:10,  3.61s/it]
#  66%|██████▌   | 165/250 [10:52<05:05,  3.60s/it]
#  66%|██████▋   | 166/250 [10:55<04:57,  3.54s/it]
#  67%|██████▋   | 167/250 [10:59<04:59,  3.61s/it]
#  67%|██████▋   | 168/250 [11:03<04:56,  3.62s/it]
#  68%|██████▊   | 169/250 [11:06<04:54,  3.64s/it]
#  68%|██████▊   | 170/250 [11:10<04:54,  3.68s/it]
#  68%|██████▊   | 171/250 [11:14<04:59,  3.79s/it]
#  69%|██████▉   | 172/250 [11:18<04:53,  3.76s/it]
#  69%|██████▉   | 173/250 [11:21<04:37,  3.61s/it]
#  70%|██████▉   | 174/250 [11:25<04:35,  3.63s/it]
#  70%|███████   | 175/250 [11:29<04:42,  3.76s/it]
#  70%|███████   | 176/250 [11:33<04:42,  3.82s/it]
#  71%|███████   | 177/250 [11:36<04:32,  3.73s/it]
#  71%|███████   | 178/250 [11:40<04:32,  3.78s/it]
#  72%|███████▏  | 179/250 [11:44<04:30,  3.81s/it]
#  72%|███████▏  | 180/250 [11:48<04:27,  3.81s/it]
#  72%|███████▏  | 181/250 [11:52<04:30,  3.92s/it]
#  73%|███████▎  | 182/250 [11:56<04:20,  3.83s/it]
#  73%|███████▎  | 183/250 [11:59<04:08,  3.71s/it]
#  74%|███████▎  | 184/250 [12:03<04:10,  3.79s/it]
#  74%|███████▍  | 185/250 [12:07<04:04,  3.76s/it]
#  74%|███████▍  | 186/250 [12:11<04:09,  3.90s/it]
#  75%|███████▍  | 187/250 [12:15<04:09,  3.95s/it]
#  75%|███████▌  | 188/250 [12:19<04:02,  3.92s/it]
#  76%|███████▌  | 189/250 [12:22<03:50,  3.78s/it]
#  76%|███████▌  | 190/250 [12:26<03:43,  3.72s/it]
#  76%|███████▋  | 191/250 [12:30<03:42,  3.77s/it]
#  77%|███████▋  | 192/250 [12:33<03:37,  3.74s/it]
#  77%|███████▋  | 193/250 [12:37<03:33,  3.74s/it]
#  78%|███████▊  | 194/250 [12:41<03:35,  3.85s/it]
#  78%|███████▊  | 195/250 [12:45<03:28,  3.79s/it]
#  78%|███████▊  | 196/250 [12:49<03:24,  3.79s/it]
#  79%|███████▉  | 197/250 [12:52<03:19,  3.76s/it]
#  79%|███████▉  | 198/250 [12:56<03:20,  3.85s/it]
#  80%|███████▉  | 199/250 [13:00<03:10,  3.73s/it]
#  80%|████████  | 200/250 [13:04<03:11,  3.82s/it]
#  80%|████████  | 201/250 [13:08<03:14,  3.97s/it]
#  81%|████████  | 202/250 [13:12<03:13,  4.04s/it]
#  81%|████████  | 203/250 [13:16<03:02,  3.89s/it]
#  82%|████████▏ | 204/250 [13:20<03:02,  3.96s/it]
#  82%|████████▏ | 205/250 [13:24<02:57,  3.95s/it]
#  82%|████████▏ | 206/250 [13:28<02:51,  3.89s/it]
#  83%|████████▎ | 207/250 [13:32<02:44,  3.84s/it]
#  83%|████████▎ | 208/250 [13:35<02:38,  3.77s/it]
#  84%|████████▎ | 209/250 [13:39<02:34,  3.77s/it]
#  84%|████████▍ | 210/250 [13:43<02:31,  3.78s/it]
#  84%|████████▍ | 211/250 [13:46<02:25,  3.74s/it]
#  85%|████████▍ | 212/250 [13:50<02:24,  3.82s/it]
#  85%|████████▌ | 213/250 [13:54<02:18,  3.74s/it]
#  86%|████████▌ | 214/250 [13:58<02:14,  3.75s/it]
#  86%|████████▌ | 215/250 [14:01<02:10,  3.72s/it]
#  86%|████████▋ | 216/250 [14:05<02:05,  3.70s/it]
#  87%|████████▋ | 217/250 [14:08<01:59,  3.63s/it]
#  87%|████████▋ | 218/250 [14:12<01:56,  3.64s/it]
#  88%|████████▊ | 219/250 [14:16<01:51,  3.59s/it]
#  88%|████████▊ | 220/250 [14:19<01:48,  3.63s/it]
#  88%|████████▊ | 221/250 [14:23<01:47,  3.72s/it]
#  89%|████████▉ | 222/250 [14:26<01:39,  3.56s/it]
#  89%|████████▉ | 223/250 [14:30<01:35,  3.52s/it]
#  90%|████████▉ | 224/250 [14:34<01:34,  3.65s/it]
#  90%|█████████ | 225/250 [14:37<01:30,  3.60s/it]
#  90%|█████████ | 226/250 [14:41<01:29,  3.73s/it]
#  91%|█████████ | 227/250 [14:45<01:24,  3.67s/it]
#  91%|█████████ | 228/250 [14:49<01:20,  3.68s/it]
#  92%|█████████▏| 229/250 [14:53<01:19,  3.81s/it]
#  92%|█████████▏| 230/250 [14:56<01:15,  3.76s/it]
#  92%|█████████▏| 231/250 [15:00<01:12,  3.80s/it]
#  93%|█████████▎| 232/250 [15:04<01:06,  3.71s/it]
#  93%|█████████▎| 233/250 [15:08<01:04,  3.77s/it]
#  94%|█████████▎| 234/250 [15:12<01:03,  4.00s/it]
#  94%|█████████▍| 235/250 [15:16<00:58,  3.89s/it]
#  94%|█████████▍| 236/250 [15:19<00:52,  3.77s/it]
#  95%|█████████▍| 237/250 [15:23<00:48,  3.71s/it]
#  95%|█████████▌| 238/250 [15:27<00:46,  3.84s/it]
#  96%|█████████▌| 239/250 [15:31<00:42,  3.85s/it]
#  96%|█████████▌| 240/250 [15:35<00:39,  3.96s/it]
#  96%|█████████▋| 241/250 [15:39<00:34,  3.81s/it]
#  97%|█████████▋| 242/250 [15:42<00:29,  3.69s/it]
#  97%|█████████▋| 243/250 [15:45<00:25,  3.65s/it]
#  98%|█████████▊| 244/250 [15:49<00:22,  3.69s/it]
#  98%|█████████▊| 245/250 [15:53<00:18,  3.67s/it]
#  98%|█████████▊| 246/250 [15:57<00:14,  3.68s/it]
#  99%|█████████▉| 247/250 [16:00<00:10,  3.56s/it]
#  99%|█████████▉| 248/250 [16:04<00:07,  3.63s/it]
# 100%|█████████▉| 249/250 [16:08<00:03,  3.80s/it]
# 100%|██████████| 250/250 [16:12<00:00,  3.89s/it]
# Avg. Loss train:  5.8548844661712645
# <ipython-input-121-b5655e1a1dbb>:78: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   hyps = np.concatenate(np.array(hypothesis))
# [list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a']) list(['a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])]
#  33%|███▎      | 1/3 [18:44<37:28, 1124.15s/it]
# Avg. Loss valid: 4.8824,         BLEU-1: 0.00, BLEU-2: 0.00, BLEU-3: 0.00, BLEU-4: 0.00
# Epoch:  1
#   0%|          | 0/250 [00:00<?, ?it/s]
#   0%|          | 1/250 [00:03<14:34,  3.51s/it]
#   1%|          | 2/250 [00:07<15:05,  3.65s/it]
#   1%|          | 3/250 [00:11<15:19,  3.72s/it]
#   2%|▏         | 4/250 [00:15<15:59,  3.90s/it]
#   2%|▏         | 5/250 [00:18<15:10,  3.71s/it]
#   2%|▏         | 6/250 [00:22<15:24,  3.79s/it]
#   3%|▎         | 7/250 [00:26<15:20,  3.79s/it]
#   3%|▎         | 8/250 [00:30<15:10,  3.76s/it]
#   4%|▎         | 9/250 [00:33<14:48,  3.69s/it]
#   4%|▍         | 10/250 [00:36<14:12,  3.55s/it]
#   4%|▍         | 11/250 [00:40<13:57,  3.51s/it]
#   5%|▍         | 12/250 [00:43<14:03,  3.54s/it]
#   5%|▌         | 13/250 [00:47<14:06,  3.57s/it]
#   6%|▌         | 14/250 [00:50<13:44,  3.50s/it]
#   6%|▌         | 15/250 [00:54<13:51,  3.54s/it]
#   6%|▋         | 16/250 [00:58<14:21,  3.68s/it]
#   7%|▋         | 17/250 [01:03<16:12,  4.17s/it]
#   7%|▋         | 18/250 [01:07<15:20,  3.97s/it]
#   8%|▊         | 19/250 [01:11<15:04,  3.91s/it]
#   8%|▊         | 20/250 [01:14<14:37,  3.82s/it]
#   8%|▊         | 21/250 [01:18<14:23,  3.77s/it]
#   9%|▉         | 22/250 [01:21<14:00,  3.69s/it]
#   9%|▉         | 23/250 [01:25<14:29,  3.83s/it]
#  10%|▉         | 24/250 [01:30<14:52,  3.95s/it]
#  10%|█         | 25/250 [01:33<14:20,  3.82s/it]
#  10%|█         | 26/250 [01:37<14:03,  3.77s/it]
#  11%|█         | 27/250 [01:40<13:15,  3.57s/it]
#  11%|█         | 28/250 [01:43<13:02,  3.52s/it]
#  12%|█▏        | 29/250 [01:47<13:28,  3.66s/it]
#  12%|█▏        | 30/250 [01:51<13:36,  3.71s/it]
#  12%|█▏        | 31/250 [01:55<13:27,  3.69s/it]
#  13%|█▎        | 32/250 [01:59<14:05,  3.88s/it]
#  13%|█▎        | 33/250 [02:03<13:52,  3.84s/it]
#  14%|█▎        | 34/250 [02:06<13:24,  3.72s/it]
#  14%|█▍        | 35/250 [02:10<13:19,  3.72s/it]
#  14%|█▍        | 36/250 [02:14<12:57,  3.64s/it]
#  15%|█▍        | 37/250 [02:18<13:39,  3.85s/it]
#  15%|█▌        | 38/250 [02:21<13:11,  3.73s/it]
#  16%|█▌        | 39/250 [02:25<13:18,  3.78s/it]
#  16%|█▌        | 40/250 [02:29<12:47,  3.66s/it]
#  16%|█▋        | 41/250 [02:32<12:41,  3.64s/it]
#  17%|█▋        | 42/250 [02:36<12:35,  3.63s/it]
#  17%|█▋        | 43/250 [02:40<13:14,  3.84s/it]
#  18%|█▊        | 44/250 [02:44<12:48,  3.73s/it]
#  18%|█▊        | 45/250 [02:47<12:34,  3.68s/it]
#  18%|█▊        | 46/250 [02:51<12:38,  3.72s/it]
#  19%|█▉        | 47/250 [02:55<12:27,  3.68s/it]
#  19%|█▉        | 48/250 [02:58<12:29,  3.71s/it]
#  20%|█▉        | 49/250 [03:02<12:09,  3.63s/it]
#  20%|██        | 50/250 [03:06<12:16,  3.68s/it]
#  20%|██        | 51/250 [03:09<11:58,  3.61s/it]
#  21%|██        | 52/250 [03:13<12:30,  3.79s/it]
#  21%|██        | 53/250 [03:17<12:23,  3.78s/it]
#  22%|██▏       | 54/250 [03:21<12:27,  3.81s/it]
#  22%|██▏       | 55/250 [03:25<12:38,  3.89s/it]
#  22%|██▏       | 56/250 [03:29<12:25,  3.84s/it]
#  23%|██▎       | 57/250 [03:33<12:21,  3.84s/it]
#  23%|██▎       | 58/250 [03:36<11:50,  3.70s/it]
#  24%|██▎       | 59/250 [03:39<11:32,  3.62s/it]
#  24%|██▍       | 60/250 [03:44<12:17,  3.88s/it]
#  24%|██▍       | 61/250 [03:47<11:49,  3.75s/it]
#  25%|██▍       | 62/250 [03:51<11:29,  3.67s/it]
#  25%|██▌       | 63/250 [03:54<11:09,  3.58s/it]
#  26%|██▌       | 64/250 [03:58<11:16,  3.64s/it]
#  26%|██▌       | 65/250 [04:02<11:33,  3.75s/it]
#  26%|██▋       | 66/250 [04:05<11:10,  3.64s/it]
#  27%|██▋       | 67/250 [04:09<10:45,  3.53s/it]
#  27%|██▋       | 68/250 [04:12<11:00,  3.63s/it]
#  28%|██▊       | 69/250 [04:16<11:00,  3.65s/it]
#  28%|██▊       | 70/250 [04:19<10:37,  3.54s/it]
#  28%|██▊       | 71/250 [04:23<10:54,  3.65s/it]
#  29%|██▉       | 72/250 [04:27<10:28,  3.53s/it]
#  29%|██▉       | 73/250 [04:30<10:24,  3.53s/it]
#  30%|██▉       | 74/250 [04:34<10:34,  3.61s/it]
#  30%|███       | 75/250 [04:37<10:31,  3.61s/it]
#  30%|███       | 76/250 [04:41<10:18,  3.56s/it]
#  31%|███       | 77/250 [04:45<10:42,  3.71s/it]
#  31%|███       | 78/250 [04:49<10:43,  3.74s/it]
#  32%|███▏      | 79/250 [04:53<10:45,  3.77s/it]
#  32%|███▏      | 80/250 [04:56<10:24,  3.67s/it]
#  32%|███▏      | 81/250 [05:00<10:24,  3.70s/it]
#  33%|███▎      | 82/250 [05:03<10:09,  3.63s/it]
#  33%|███▎      | 83/250 [05:07<10:13,  3.67s/it]
#  34%|███▎      | 84/250 [05:10<09:51,  3.57s/it]
#  34%|███▍      | 85/250 [05:14<09:49,  3.58s/it]
#  34%|███▍      | 86/250 [05:18<09:46,  3.58s/it]
#  35%|███▍      | 87/250 [05:21<09:50,  3.62s/it]
#  35%|███▌      | 88/250 [05:25<09:36,  3.56s/it]
#  36%|███▌      | 89/250 [05:28<09:35,  3.58s/it]
#  36%|███▌      | 90/250 [05:32<09:28,  3.55s/it]
#  36%|███▋      | 91/250 [05:36<10:08,  3.83s/it]
#  37%|███▋      | 92/250 [05:40<09:48,  3.73s/it]
#  37%|███▋      | 93/250 [05:44<10:03,  3.85s/it]
#  38%|███▊      | 94/250 [05:48<09:54,  3.81s/it]
#  38%|███▊      | 95/250 [05:51<09:44,  3.77s/it]
#  38%|███▊      | 96/250 [05:55<09:25,  3.67s/it]
#  39%|███▉      | 97/250 [05:58<09:10,  3.59s/it]
#  39%|███▉      | 98/250 [06:02<09:11,  3.63s/it]
#  40%|███▉      | 99/250 [06:06<09:08,  3.63s/it]
#  40%|████      | 100/250 [06:10<09:23,  3.76s/it]
#  40%|████      | 101/250 [06:13<09:10,  3.70s/it]
#  41%|████      | 102/250 [06:17<09:00,  3.65s/it]
#  41%|████      | 103/250 [06:20<08:45,  3.58s/it]
#  42%|████▏     | 104/250 [06:24<08:52,  3.64s/it]
#  42%|████▏     | 105/250 [06:28<08:56,  3.70s/it]
#  42%|████▏     | 106/250 [06:31<08:46,  3.66s/it]
#  43%|████▎     | 107/250 [06:35<08:28,  3.56s/it]
#  43%|████▎     | 108/250 [06:39<08:53,  3.76s/it]
#  44%|████▎     | 109/250 [06:43<09:08,  3.89s/it]
#  44%|████▍     | 110/250 [06:47<09:09,  3.93s/it]
#  44%|████▍     | 111/250 [06:50<08:45,  3.78s/it]
#  45%|████▍     | 112/250 [06:54<08:34,  3.73s/it]
#  45%|████▌     | 113/250 [06:57<08:09,  3.57s/it]
#  46%|████▌     | 114/250 [07:01<08:18,  3.66s/it]
#  46%|████▌     | 115/250 [07:05<08:09,  3.62s/it]
#  46%|████▋     | 116/250 [07:09<08:21,  3.74s/it]
#  47%|████▋     | 117/250 [07:12<08:09,  3.68s/it]
#  47%|████▋     | 118/250 [07:16<07:55,  3.60s/it]
#  48%|████▊     | 119/250 [07:20<08:10,  3.74s/it]
#  48%|████▊     | 120/250 [07:23<08:01,  3.70s/it]
#  48%|████▊     | 121/250 [07:27<07:53,  3.67s/it]
#  49%|████▉     | 122/250 [07:31<07:53,  3.70s/it]
#  49%|████▉     | 123/250 [07:35<08:05,  3.82s/it]
#  50%|████▉     | 124/250 [07:39<08:01,  3.82s/it]
#  50%|█████     | 125/250 [07:42<07:39,  3.67s/it]
#  50%|█████     | 126/250 [07:46<07:35,  3.68s/it]
#  51%|█████     | 127/250 [07:49<07:32,  3.68s/it]
#  51%|█████     | 128/250 [07:53<07:19,  3.60s/it]
#  52%|█████▏    | 129/250 [07:57<07:23,  3.67s/it]
#  52%|█████▏    | 130/250 [08:00<07:03,  3.53s/it]
#  52%|█████▏    | 131/250 [08:03<07:06,  3.58s/it]
#  53%|█████▎    | 132/250 [08:07<07:00,  3.57s/it]
#  53%|█████▎    | 133/250 [08:11<06:59,  3.58s/it]
#  54%|█████▎    | 134/250 [08:14<06:51,  3.55s/it]
#  54%|█████▍    | 135/250 [08:18<06:47,  3.54s/it]
#  54%|█████▍    | 136/250 [08:21<06:47,  3.58s/it]
#  55%|█████▍    | 137/250 [08:25<06:42,  3.57s/it]
#  55%|█████▌    | 138/250 [08:29<06:53,  3.69s/it]
#  56%|█████▌    | 139/250 [08:32<06:46,  3.66s/it]
#  56%|█████▌    | 140/250 [08:37<07:08,  3.89s/it]
#  56%|█████▋    | 141/250 [08:41<07:02,  3.88s/it]
#  57%|█████▋    | 142/250 [08:44<06:56,  3.86s/it]
#  57%|█████▋    | 143/250 [08:48<06:45,  3.79s/it]
#  58%|█████▊    | 144/250 [08:51<06:28,  3.67s/it]
#  58%|█████▊    | 145/250 [08:55<06:21,  3.63s/it]
#  58%|█████▊    | 146/250 [08:59<06:20,  3.66s/it]
#  59%|█████▉    | 147/250 [09:03<06:31,  3.80s/it]
#  59%|█████▉    | 148/250 [09:07<06:31,  3.84s/it]
#  60%|█████▉    | 149/250 [09:11<06:30,  3.87s/it]
#  60%|██████    | 150/250 [09:15<06:44,  4.05s/it]
#  60%|██████    | 151/250 [09:19<06:33,  3.97s/it]
#  61%|██████    | 152/250 [09:23<06:25,  3.93s/it]
#  61%|██████    | 153/250 [09:27<06:16,  3.89s/it]
#  62%|██████▏   | 154/250 [09:31<06:15,  3.92s/it]
#  62%|██████▏   | 155/250 [09:34<05:59,  3.78s/it]
#  62%|██████▏   | 156/250 [09:38<05:53,  3.76s/it]
#  63%|██████▎   | 157/250 [09:42<05:52,  3.79s/it]
#  63%|██████▎   | 158/250 [09:45<05:47,  3.78s/it]
#  64%|██████▎   | 159/250 [09:49<05:38,  3.72s/it]
#  64%|██████▍   | 160/250 [09:53<05:35,  3.73s/it]
#  64%|██████▍   | 161/250 [09:56<05:25,  3.65s/it]
#  65%|██████▍   | 162/250 [10:00<05:16,  3.60s/it]
#  65%|██████▌   | 163/250 [10:03<05:15,  3.63s/it]
#  66%|██████▌   | 164/250 [10:07<05:13,  3.65s/it]
#  66%|██████▌   | 165/250 [10:11<05:14,  3.70s/it]
#  66%|██████▋   | 166/250 [10:14<05:04,  3.63s/it]
#  67%|██████▋   | 167/250 [10:18<04:59,  3.61s/it]
#  67%|██████▋   | 168/250 [10:21<04:47,  3.50s/it]
#  68%|██████▊   | 169/250 [10:25<04:48,  3.56s/it]
#  68%|██████▊   | 170/250 [10:29<04:54,  3.68s/it]
#  68%|██████▊   | 171/250 [10:33<04:54,  3.73s/it]
#  69%|██████▉   | 172/250 [10:36<04:44,  3.65s/it]
#  69%|██████▉   | 173/250 [10:40<04:36,  3.60s/it]
#  70%|██████▉   | 174/250 [10:43<04:27,  3.52s/it]
#  70%|███████   | 175/250 [10:47<04:26,  3.55s/it]
#  70%|███████   | 176/250 [10:51<04:40,  3.80s/it]
#  71%|███████   | 177/250 [10:54<04:24,  3.63s/it]
#  71%|███████   | 178/250 [10:58<04:23,  3.66s/it]
#  72%|███████▏  | 179/250 [11:02<04:17,  3.63s/it]
#  72%|███████▏  | 180/250 [11:05<04:15,  3.64s/it]
#  72%|███████▏  | 181/250 [11:08<04:03,  3.52s/it]
#  73%|███████▎  | 182/250 [11:12<04:03,  3.58s/it]
#  73%|███████▎  | 183/250 [11:16<03:57,  3.55s/it]
#  74%|███████▎  | 184/250 [11:19<03:55,  3.57s/it]
#  74%|███████▍  | 185/250 [11:23<03:58,  3.67s/it]
#  74%|███████▍  | 186/250 [11:27<04:08,  3.88s/it]
#  75%|███████▍  | 187/250 [11:31<03:55,  3.74s/it]
#  75%|███████▌  | 188/250 [11:35<03:52,  3.75s/it]
#  76%|███████▌  | 189/250 [11:38<03:49,  3.76s/it]
#  76%|███████▌  | 190/250 [11:42<03:42,  3.71s/it]
#  76%|███████▋  | 191/250 [11:46<03:39,  3.71s/it]
#  77%|███████▋  | 192/250 [11:50<03:36,  3.73s/it]
#  77%|███████▋  | 193/250 [11:53<03:30,  3.69s/it]
#  78%|███████▊  | 194/250 [11:57<03:25,  3.68s/it]
#  78%|███████▊  | 195/250 [12:00<03:19,  3.62s/it]
#  78%|███████▊  | 196/250 [12:04<03:18,  3.68s/it]
#  79%|███████▉  | 197/250 [12:08<03:15,  3.69s/it]
#  79%|███████▉  | 198/250 [12:12<03:17,  3.80s/it]
#  80%|███████▉  | 199/250 [12:16<03:13,  3.79s/it]
#  80%|████████  | 200/250 [12:20<03:14,  3.89s/it]
#  80%|████████  | 201/250 [12:24<03:12,  3.92s/it]
#  81%|████████  | 202/250 [12:28<03:07,  3.91s/it]
#  81%|████████  | 203/250 [12:31<02:56,  3.76s/it]
#  82%|████████▏ | 204/250 [12:34<02:47,  3.63s/it]
#  82%|████████▏ | 205/250 [12:38<02:42,  3.61s/it]
#  82%|████████▏ | 206/250 [12:42<02:39,  3.63s/it]
#  83%|████████▎ | 207/250 [12:46<02:40,  3.74s/it]
#  83%|████████▎ | 208/250 [12:50<02:43,  3.89s/it]
#  84%|████████▎ | 209/250 [12:54<02:36,  3.83s/it]
#  84%|████████▍ | 210/250 [12:57<02:32,  3.80s/it]
#  84%|████████▍ | 211/250 [13:01<02:27,  3.79s/it]
#  85%|████████▍ | 212/250 [13:04<02:19,  3.67s/it]
#  85%|████████▌ | 213/250 [13:08<02:17,  3.71s/it]
#  86%|████████▌ | 214/250 [13:12<02:16,  3.78s/it]
#  86%|████████▌ | 215/250 [13:16<02:13,  3.82s/it]
#  86%|████████▋ | 216/250 [13:20<02:08,  3.79s/it]
#  87%|████████▋ | 217/250 [13:23<02:03,  3.75s/it]
#  87%|████████▋ | 218/250 [13:27<01:58,  3.71s/it]
#  88%|████████▊ | 219/250 [13:31<01:53,  3.65s/it]
#  88%|████████▊ | 220/250 [13:34<01:46,  3.57s/it]
#  88%|████████▊ | 221/250 [13:38<01:46,  3.66s/it]
#  89%|████████▉ | 222/250 [13:41<01:40,  3.60s/it]
#  89%|████████▉ | 223/250 [13:45<01:34,  3.51s/it]
#  90%|████████▉ | 224/250 [13:48<01:31,  3.52s/it]
#  90%|█████████ | 225/250 [13:52<01:29,  3.58s/it]
#  90%|█████████ | 226/250 [13:56<01:29,  3.71s/it]
#  91%|█████████ | 227/250 [13:59<01:23,  3.61s/it]
#  91%|█████████ | 228/250 [14:03<01:19,  3.60s/it]
#  92%|█████████▏| 229/250 [14:08<01:26,  4.11s/it]
#  92%|█████████▏| 230/250 [14:13<01:24,  4.21s/it]
#  92%|█████████▏| 231/250 [14:16<01:17,  4.09s/it]
#  93%|█████████▎| 232/250 [14:20<01:12,  4.05s/it]
#  93%|█████████▎| 233/250 [14:24<01:06,  3.91s/it]
#  94%|█████████▎| 234/250 [14:27<01:00,  3.81s/it]
#  94%|█████████▍| 235/250 [14:31<00:56,  3.77s/it]
#  94%|█████████▍| 236/250 [14:35<00:51,  3.67s/it]
#  95%|█████████▍| 237/250 [14:38<00:48,  3.74s/it]
#  95%|█████████▌| 238/250 [14:43<00:46,  3.84s/it]
#  96%|█████████▌| 239/250 [14:46<00:41,  3.74s/it]
#  96%|█████████▌| 240/250 [14:50<00:37,  3.77s/it]
#  96%|█████████▋| 241/250 [14:53<00:33,  3.69s/it]
#  97%|█████████▋| 242/250 [14:57<00:29,  3.64s/it]
#  97%|█████████▋| 243/250 [15:02<00:27,  3.92s/it]
#  98%|█████████▊| 244/250 [15:05<00:22,  3.79s/it]
#  98%|█████████▊| 245/250 [15:08<00:18,  3.69s/it]
#  98%|█████████▊| 246/250 [15:12<00:14,  3.69s/it]
#  99%|█████████▉| 247/250 [15:16<00:10,  3.61s/it]
#  99%|█████████▉| 248/250 [15:19<00:07,  3.62s/it]
# 100%|█████████▉| 249/250 [15:22<00:03,  3.50s/it]
# 100%|██████████| 250/250 [15:26<00:00,  3.71s/it]
# Avg. Loss train:  4.991335475921631
# [list(['a', 'dog', 'dog', 'dog', 'dog', 'the'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'the'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'the'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'the'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'the'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'a', 'a', 'a', 'a', 'a', 'a'])
# ...
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'in', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a']) list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'in', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'in', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a']) list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a']) list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'in', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'in', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'in', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'in', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a']) list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a'])
#  list(['a', 'man', 'in', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a']) list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'a', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a'])
#  list(['a', 'dog', 'dog', 'dog', 'dog', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a'])
#  list(['a', 'man', 'in', 'in', 'a', 'a'])
#  list(['a', 'man', 'a', 'a', 'a', 'a', 'a', 'a'])]
# 100%|██████████| 3/3 [54:27<00:00, 1089.05s/it]
# Avg. Loss valid: 4.7013,         BLEU-1: 0.00, BLEU-2: 0.00, BLEU-3: 0.00, BLEU-4: 0.00
